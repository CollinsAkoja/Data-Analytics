# %% [markdown]
# ## Alcohol Consumption Rate

# %%
import pandas as pd

# %%
# model = "Alcohol"
model = pd.read_csv(r"c:\Users\RICHMAN\Desktop\Dayta Analysis_Projects\dbms\alcohol-available-for-consumption-year-ended-december-2024.csv")

# %%
model
# Out:
#        Unnamed: 0 Unnamed: 1 Series_reference   Period  Data_value  \
# 0            1935        Dec          ALCA.S1  1935.12   51.100000
# 1            1936        Dec          ALCA.S1  1936.12   58.700000
# 2            1937        Dec          ALCA.S1  1937.12   68.700000
# 3            1938        Dec          ALCA.S1  1938.12   78.100000
# 4            1939        Dec          ALCA.S1  1939.12   79.200000
# ...           ...        ...              ...      ...         ...
# 14111        2023        Dec        ALCQ.SAZZ  2023.12  138.291331
# 14112        2024        Mar        ALCQ.SAZZ  2024.03  111.690091
# 14113        2024        Jun        ALCQ.SAZZ  2024.06  104.757144
# 14114        2024        Sep        ALCQ.SAZZ  2024.09  109.401595
# 14115        2024        Dec        ALCQ.SAZZ  2024.12  156.444269
#
#             STATUS   UNITS  MAGNTUDE                                  Subject  \
# 0            FINAL  Litres         6  Alcohol Available for Consumption - ALC
# ...

# %%
model.isnull()
# Out:
#        Unnamed: 0  Unnamed: 1  Series_reference  Period  Data_value  STATUS  \
# 0           False       False             False   False       False   False
# 1           False       False             False   False       False   False
# 2           False       False             False   False       False   False
# 3           False       False             False   False       False   False
# 4           False       False             False   False       False   False
# ...           ...         ...               ...     ...         ...     ...
# 14111       False       False             False   False       False   False
# 14112       False       False             False   False       False   False
# 14113       False       False             False   False       False   False
# 14114       False       False             False   False       False   False
# 14115       False       False             False   False       False   False
#
# ...

# %%
model.isnull().sum()
# Out:
# Unnamed: 0              0
# Unnamed: 1              0
# Series_reference        0
# Period                  0
# Data_value              5
# STATUS                  0
# UNITS                   0
# MAGNTUDE                0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2      14116
# Series_title_3      14116
# Series_title_4      14116
# Series_title_5      14116
# dtype: int64

# %%
# model.fillna()

# %%
# model.duplicate().sum()

# %%
# model.drop-duplicates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 model.drop-duplicates()
#
# NameError: name 'duplicates' is not defined
